# %%
# importing libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
#image processing

# %%
# ImageDataGenerator: This is a class from Keras used for generating batches of tensor image data with real-time data augmentation.
#training_set': This is the directory where the training images are located

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
        'training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 3572 images belonging to 5 classes.

# %%
# test_datagon:This is the directory where the test images are located.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
        'test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 745 images belonging to 5 classes.

# %%
cnn = tf.keras.models.Sequential() #data flow will be sequential with the keras model

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64 , kernel_size=3 , activation='relu' , input_shape=[64,64,3])) 
# This adds a 2D convolutional layer to the model.
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))
#adds a max-pooling layer to our convolutional neural network (CNN) model.

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64 , kernel_size=3 , activation='relu' ))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2 , strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.5)) # dropout:  commonly used in neural networks to prevent overfitting

# %%
cnn.add(tf.keras.layers.Flatten()) # covert the 3d model to the 1d moedel

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=5 , activation='softmax'))

# %%
cnn.compile(optimizer = 'rmsprop' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
cnn.fit(x = training_set , validation_data = test_set , epochs = 30)
# Out:
# Epoch 1/30
# 112/112 [==============================] - 123s 1s/step - loss: 1.4154 - accuracy: 0.3911 - val_loss: 1.0604 - val_accuracy: 0.5946
# Epoch 2/30
# 112/112 [==============================] - 22s 200ms/step - loss: 1.1228 - accuracy: 0.5428 - val_loss: 0.9892 - val_accuracy: 0.6174
# Epoch 3/30
# 112/112 [==============================] - 24s 216ms/step - loss: 1.0184 - accuracy: 0.6041 - val_loss: 1.0287 - val_accuracy: 0.6081
# Epoch 4/30
# 112/112 [==============================] - 25s 223ms/step - loss: 0.9428 - accuracy: 0.6305 - val_loss: 1.5303 - val_accuracy: 0.4698
# Epoch 5/30
# 112/112 [==============================] - 27s 240ms/step - loss: 0.8896 - accuracy: 0.6576 - val_loss: 0.9408 - val_accuracy: 0.6362
# Epoch 6/30
# 112/112 [==============================] - 26s 236ms/step - loss: 0.8283 - accuracy: 0.6797 - val_loss: 0.8774 - val_accuracy: 0.6510
# Epoch 7/30
# 112/112 [==============================] - 22s 196ms/step - loss: 0.8061 - accuracy: 0.6937 - val_loss: 0.8262 - val_accuracy: 0.6792
# Epoch 8/30
# 112/112 [==============================] - 22s 195ms/step - loss: 0.7560 - accuracy: 0.7111 - val_loss: 0.7532 - val_accuracy: 0.7208
# Epoch 9/30
# 112/112 [==============================] - 22s 198ms/step - loss: 0.7306 - accuracy: 0.7214 - val_loss: 0.7756 - val_accuracy: 0.7007
# Epoch 10/30
# 112/112 [==============================] - 23s 201ms/step - loss: 0.6777 - accuracy: 0.7419 - val_loss: 0.9083 - val_accuracy: 0.6913
# Epoch 11/30
# 112/112 [==============================] - 22s 197ms/step - loss: 0.6763 - accuracy: 0.7405 - val_loss: 0.8915 - val_accuracy: 0.6886
# Epoch 12/30
# 112/112 [==============================] - 22s 197ms/step - loss: 0.6392 - accuracy: 0.7567 - val_loss: 0.8250 - val_accuracy: 0.7020
# Epoch 13/30
# 112/112 [==============================] - 22s 198ms/step - loss: 0.5949 - accuracy: 0.7808 - val_loss: 0.9208 - val_accuracy: 0.6604
# Epoch 14/30
# 112/112 [==============================] - 23s 203ms/step - loss: 0.5877 - accuracy: 0.7763 - val_loss: 0.8262 - val_accuracy: 0.7060
# Epoch 15/30
# 112/112 [==============================] - 22s 192ms/step - loss: 0.5669 - accuracy: 0.7895 - val_loss: 0.9804 - val_accuracy: 0.6671
# Epoch 16/30
# 112/112 [==============================] - 22s 200ms/step - loss: 0.5476 - accuracy: 0.8001 - val_loss: 0.7767 - val_accuracy: 0.7262
# Epoch 17/30
# 112/112 [==============================] - 23s 203ms/step - loss: 0.5156 - accuracy: 0.7984 - val_loss: 0.8332 - val_accuracy: 0.7087
# Epoch 18/30
# 112/112 [==============================] - 22s 195ms/step - loss: 0.4938 - accuracy: 0.8222 - val_loss: 0.8720 - val_accuracy: 0.6966
# Epoch 19/30
# 112/112 [==============================] - 22s 200ms/step - loss: 0.4801 - accuracy: 0.8275 - val_loss: 0.8294 - val_accuracy: 0.7087
# Epoch 20/30
# 112/112 [==============================] - 22s 197ms/step - loss: 0.4647 - accuracy: 0.8354 - val_loss: 0.9119 - val_accuracy: 0.6993
# Epoch 21/30
# 112/112 [==============================] - 22s 194ms/step - loss: 0.4472 - accuracy: 0.8298 - val_loss: 0.8827 - val_accuracy: 0.7114
# Epoch 22/30
# 112/112 [==============================] - 22s 197ms/step - loss: 0.4394 - accuracy: 0.8385 - val_loss: 0.8352 - val_accuracy: 0.7208
# Epoch 23/30
# 112/112 [==============================] - 22s 200ms/step - loss: 0.4216 - accuracy: 0.8443 - val_loss: 1.1290 - val_accuracy: 0.6711
# Epoch 24/30
# 112/112 [==============================] - 22s 198ms/step - loss: 0.4007 - accuracy: 0.8522 - val_loss: 0.9478 - val_accuracy: 0.7141
# Epoch 25/30
# 112/112 [==============================] - 22s 200ms/step - loss: 0.3960 - accuracy: 0.8586 - val_loss: 1.0198 - val_accuracy: 0.6872
# Epoch 26/30
# 112/112 [==============================] - 22s 197ms/step - loss: 0.3522 - accuracy: 0.8707 - val_loss: 0.8824 - val_accuracy: 0.7060
# Epoch 27/30
# 112/112 [==============================] - 22s 195ms/step - loss: 0.3638 - accuracy: 0.8639 - val_loss: 1.0712 - val_accuracy: 0.6591
# Epoch 28/30
# 112/112 [==============================] - 22s 196ms/step - loss: 0.3396 - accuracy: 0.8771 - val_loss: 0.9488 - val_accuracy: 0.7141
# Epoch 29/30
# 112/112 [==============================] - 22s 194ms/step - loss: 0.3300 - accuracy: 0.8816 - val_loss: 0.9714 - val_accuracy: 0.7114
# Epoch 30/30
# 112/112 [==============================] - 22s 193ms/step - loss: 0.3140 - accuracy: 0.8936 - val_loss: 1.0636 - val_accuracy: 0.6966

# %%
from keras.preprocessing import image
test_image =tf.keras.utils.load_img('prediction/dan.jpg',target_size=(64,64))
test_image =tf.keras.utils.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
training_set.class_indices
# Out:
# 1/1 [==============================] - 0s 16ms/step
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
categories = ["daisy", "dandelion", "rose", "sunflower" , "tulip"]

# %%
import matplotlib.pyplot as plt
predicted_class = categories[np.argmax(result)]
test_image =tf.keras.utils.load_img('prediction/dan.jpg',target_size=(200,200))
plt.imshow(test_image)
plt.title(predicted_class)  
plt.show()
#test_image = tf.keras.utils.img_to_array(test_image)
#test_image = np.expand_dims(test_image,axis=0)

# %%
print(result)
# Out:
# [[0. 0. 0. 0. 1.]]

# %%
category=["Daisy", "Dandaline", "Rose", "Sunflower", "tulip"]
if result[0][0]==1:
    print('Daisy')
elif result[0][1]==1:
    print('Dandelion')
elif result[0][2]==1:
    print('Rose')
elif result[0][3]==1:
    print('SunFlower')
elif result[0][4]==1:
    print("Tulip")
# Out:
# Tulip
